# %%
import pandas as pd
df = pd.read_csv(
    'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv'
)
df.head()
df.groupby('species').mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
df.boxplot(by='species', ax=plt.gca(), sym='')
# Out:
# C:\Users\narah\Anaconda3\lib\site-packages\pandas\plotting\_core.py:2254: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   return_type=return_type, **kwds)
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024BEF4AFF28>,
# ...
#       dtype=object)

# %%
import matplotlib.pyplot as plt # canonical name
plt.plot([1, 2, 3, 4],'ro-' )
plt.ylabel('Integers')
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 8, 27, 64],'ro-' ) # X values are explicit
plt.xlabel('Integers')           # X-axis label
plt.ylabel('Cubes')              # Y-axis label
plt.title('Cubes of integegers') # Overall title
# Out:
# Text(0.5, 1.0, 'Cubes of integegers')

# %%
from bokeh.plotting import figure, output_file, show

# Create/Get data to plot
x = [1, 2, 3, 4, 5]
y = [10, 5, 12, 8, 20]

# Location of the javascript graph
output_file("bokeh.html")

# Build the graph by operating on the figure object
p = figure(title="small example")
p.line(x, y)

# This will open a new tab showing bokeh.html file
show(p)

# %%
from bokeh.io import output_notebook
output_notebook()

x = [1, 2, 3, 4, 5]
y = [10, 5, 12, 8, 20]

p = figure(title="small example")
p.line(x, y)
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1113">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="7c72cc6e-560a-4a47-bb70-fa02bccc4b7b" data-root-id="1114"></div>

# %%
from bokeh.plotting import figure, show
from numpy import pi

# Mark the start and end of each section
percents = [0, 0.3, 0.4, 0.6, 0.9, 1]
starts = [p*2*pi for p in percents[:-1]]
ends = [p*2*pi for p in percents[1:]]
colors = ["red", "green", "blue", "orange", "yellow"]

p = figure()
p.wedge(x=0, y=0, radius=1, start_angle=starts, end_angle=ends, color=colors)
show(p)
# Out:
#   <div class="bk-root" id="30cdfcdd-e053-4d78-b883-eb06e7d04030" data-root-id="1274"></div>

# %%
##Predict the possibility for the next player to choose American civilization based on the ACTIVEDAYS,LEADERMOSTSELECTED,PlayerID
## predict the possibilit for the next player choose Rossevelt as  leader
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_excel('C:/naraharitransactions/AddmissionsInfo/ALY6140 72241 Analytics Systems Technology SEC 11 Fall 2019 CPS/Week4/civ6_players.xlsx')

# %%
import sklearn
from sklearn import ensemble
from patsy import dmatrices
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.datasets.samples_generator import make_blobs
from sklearn.neighbors import KNeighborsClassifier
isAmerica = df['CIVILIZATIONMOSTSELECTED'] == 'CIVILIZATION_AMERICA'
dfamerica = df[isAmerica][['CIVILIZATIONMOSTSELECTED','ACTIVEDAYS','LEADERMOSTSELECTED']]
##yPred,Xpred = dmatrices('CIVILIZATIONMOSTSELECTED ~ ACTIVEDAYS + LEADERMOSTSELECTED', data = dfamerica.head(50000))
##yPred,Xpred = dfamerica(n_samples=5000, centers=2, n_features=18, random_state=1)
##yprd,Xprd = dmatrices(data = dfamerica.head(50000))
##y,X = dmatrices('CIVILIZATIONMOSTSELECTED ~ ACTIVEDAYS + LEADERMOSTSELECTED', data = df.head(50000))
##print("y:{}".format(y.shape))
##print("X:{}".format(X.shape))
##dfa.head(10) 
df = df[['CIVILIZATIONMOSTSELECTED','ACTIVEDAYS','LEADERMOSTSELECTED']]
knn = sklearn.neighbors.KNeighborsClassifier()
res = knn.fit(df, dfamerica)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-3be8173d8ea2> in <module>
#      17 df = df[['CIVILIZATIONMOSTSELECTED','ACTIVEDAYS','LEADERMOSTSELECTED']]
#      18 knn = sklearn.neighbors.KNeighborsClassifier()
# ---> 19 res = knn.fit(df, dfamerica)
#      20
#      21
#
# ~\Anaconda3\lib\site-packages\sklearn\neighbors\base.py in fit(self, X, y)
#     890         """
#     891         if not isinstance(X, (KDTree, BallTree)):
# --> 892             X, y = check_X_y(X, y, "csr", multi_output=True)
#     893
#     894         if y.ndim == 1 or y.ndim == 2 and y.shape[1] == 1:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...

# %%
plt.plot(X[:,1], y, '.')
plt.plot(X[:,1], model.predict(X), '.')
plt.xlabel('CIVILIZATIONMOSTSELECTED')
plt.ylabel('predicted')
plt.title('Trend')
# Out:
# Text(0.5, 1.0, 'Trend')
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x0000024BEF399400> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# ~\Anaconda3\lib\site-packages\matplotlib\_pylab_helpers.py in draw_all(cls, force)
#     126         for f_mgr in cls.get_all_fig_managers():
#     127             if force or f_mgr.canvas.figure.stale:
# --> 128                 f_mgr.canvas.draw_idle()
#     129
#     130 atexit.register(Gcf.destroy_all)
#
# ~\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
# ...

# %%
import seaborn as sns
sns.distplot(model.predict(X))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-e7eeeb00bc2d> in <module>
#       1 import seaborn as sns
# ----> 2 sns.distplot(model.predict(X))
#
# ~\Anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     223         hist_color = hist_kws.pop("color", color)
#     224         ax.hist(a, bins, orientation=orientation,
# --> 225                 color=hist_color, **hist_kws)
#     226         if hist_color != color:
#     227             hist_kws["color"] = hist_color
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
# ...
